# %%
import pandas
import numpy
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
data_test = pandas.read_csv('../database/traffic_site_test.csv', sep=';')
data_test.head()
# Out:
#    visitNumber  isMobile  visits  hits  pageviews  bounces  newVisits  \
# 0            1     False       1     1          1        1          1
# 1            4     False       1     3          3        0          0
# 2            3      True       1    11         10        0          0
# 3            1      True       1     1          1        1          1
# 4            1     False       1     1          1        1          1
#
#    isTrueDirect  buy  year  ...  medium_affiliate  medium_cpc  medium_cpm  \
# 0         False    0  2017  ...             False       False       False
# 1          True    0  2017  ...             False       False       False
# 2         False    0  2017  ...             False       False       False
# 3         False    0  2016  ...             False       False       False
# 4         False    0  2017  ...             False       False       False
#
#    medium_organic  medium_referral  time_range_dia  time_range_madrugada  \
# 0            True            False           False                 False
# 1            True            False           False                 False
# 2            True            False           False                  True
# 3            True            False           False                 False
# 4            True            False           False                 False
#
#    time_range_noche  time_range_tarde  transactionRevenue
# 0              True             False                 0.0
# 1             False              True                 0.0
# 2             False             False                 0.0
# 3              True             False                 0.0
# 4              True             False                 0.0
#
# [5 rows x 10297 columns]

# %%
data_train = pandas.read_csv('../database/traffic_site_train.csv', sep=';')
data_train.head()
# Out:
#    visitNumber  isMobile  visits  hits  pageviews  bounces  newVisits  \
# 0            1     False       1     2          2        0          1
# 1            1     False       1     2          2        0          1
# 2            1      True       1     1          1        1          1
# 3            3     False       1     1          1        1          0
# 4            1      True       1     1          1        1          1
#
#    isTrueDirect  buy  year  ...  medium_affiliate  medium_cpc  medium_cpm  \
# 0         False    0  2017  ...             False       False       False
# 1         False    0  2017  ...             False       False       False
# 2         False    0  2017  ...             False       False       False
# 3          True    0  2017  ...             False       False       False
# 4         False    0  2017  ...             False       False       False
#
#    medium_organic  medium_referral  time_range_dia  time_range_madrugada  \
# 0            True            False            True                 False
# 1            True            False           False                  True
# 2           False             True           False                  True
# 3           False             True           False                 False
# 4            True            False           False                  True
#
#    time_range_noche  time_range_tarde  transactionRevenue
# 0             False             False                 0.0
# 1             False             False                 0.0
# 2             False             False                 0.0
# 3             False              True                 0.0
# 4             False             False                 0.0
#
# [5 rows x 10297 columns]

# %%
x_train = data_train.drop(columns='transactionRevenue')
y_train = data_train['transactionRevenue']

x_test = data_test.drop(columns='transactionRevenue')
y_test = data_test['transactionRevenue']

# %% [markdown]
# Entrenamos el modelo

# %%
model = RandomForestRegressor(random_state=123)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=123)

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# Evaluamos el desempeño

# %%
r2 = r2_score(y_test, predictions)
rmse = numpy.sqrt(mean_squared_error(y_test, predictions))

print(f'r2: {r2}')
print(f'rmse: {rmse}')
# Out:
# r2: 0.2632379757728217
# rmse: 16748609.752990792
