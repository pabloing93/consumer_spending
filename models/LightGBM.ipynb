# %%
import pandas
import numpy
from sklearn.metrics import r2_score, mean_squared_error
import lightgbm as lgbm

# %%
data_test = pandas.read_csv('../database/traffic_site_test.csv', sep=';')
data_test.head()
# Out:
#    visitNumber  browser  operatingSystem  isMobile  deviceCategory  country  \
# 0            1        5                9     False               0       74
# 1            4        5                6     False               0      138
# 2            3        5                1      True               1      138
# 3            1        5                1      True               1       43
# 4            1        5                5     False               0      138
#
#    visits  hits  pageviews  bounces  ...  medium  isTrueDirect  buy  year  \
# 0       1     1          1        1  ...       5         False    0  2017
# 1       1     3          3        0  ...       5          True    0  2017
# 2       1    11         10        0  ...       5         False    0  2017
# 3       1     1          1        1  ...       5         False    0  2016
# 4       1     1          1        1  ...       5         False    0  2017
#
#    month  day  quarterMonth  weekday  time_range  transactionRevenue
# 0      1   28             1        5           3                 0.0
# 1      4   25             2        1           4                 0.0
# 2      2   15             1        2           1                 0.0
# 3     12   16             4        4           3                 0.0
# 4      5   16             2        1           3                 0.0
#
# [5 rows x 23 columns]

# %%
data_train = pandas.read_csv('../database/traffic_site_train.csv', sep=';')
data_train.head()
# Out:
#    visitNumber  browser  operatingSystem  isMobile  deviceCategory  country  \
# 0            1        5                9     False               0       63
# 1            1        5                9     False               0        5
# 2            1       19               11      True               1      138
# 3            3        5                6     False               0      138
# 4            1       18               11      True               1      138
#
#    visits  hits  pageviews  bounces  ...  medium  isTrueDirect  buy  year  \
# 0       1     2          2        0  ...       5         False    0  2017
# 1       1     2          2        0  ...       5         False    0  2017
# 2       1     1          1        1  ...       6         False    0  2017
# 3       1     1          1        1  ...       6          True    0  2017
# 4       1     1          1        1  ...       5         False    0  2017
#
#    month  day  quarterMonth  weekday  time_range  transactionRevenue
# 0      3   20             1        0           0                 0.0
# 1      3    3             1        4           1                 0.0
# 2      7    2             3        6           1                 0.0
# 3      2   28             1        1           4                 0.0
# 4      7    1             3        5           1                 0.0
#
# [5 rows x 23 columns]

# %%
x_train = data_train.drop(columns='transactionRevenue')
y_train = data_train['transactionRevenue']

x_test = data_test.drop(columns='transactionRevenue')
y_test = data_test['transactionRevenue']

# %% [markdown]
# Entrenamos el modelo

# %%
model = lgbm.LGBMRegressor(random_state=123)
model.fit(x_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000943 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 414
# [LightGBM] [Info] Number of data points in the train set: 8598, number of used features: 21
# [LightGBM] [Info] Start training from score 1471951.605490
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(random_state=123)

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array([-7.80271922e+01,  1.40038622e+03,  9.91146265e+04, ...,
#        -7.39825731e+01, -7.39825731e+01,  1.40038622e+03])

# %% [markdown]
# Evaluamos el desempeño

# %%
r2 = r2_score(y_test, predictions)
rmse = numpy.sqrt(mean_squared_error(y_test, predictions))

print(f'r2: {r2}')
print(f'rmse: {rmse}')
# Out:
# r2: 0.34243800793719237
# rmse: 15822805.825537005
